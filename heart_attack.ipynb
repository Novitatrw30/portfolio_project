# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart_attack_south_africa.csv',  index_col = 0)

# %%
df.head()
# Out:
#             Age  Gender  Cholesterol_Level  Blood_Pressure_Systolic  \
# Patient_ID
# 1            76  Female                156                       94
# 2            39  Female                160                      185
# 3            85    Male                254                      173
# 4            45  Female                261                      187
# 5            48    Male                206                      189
#
#             Blood_Pressure_Diastolic Smoking_Status Alcohol_Intake  \
# Patient_ID
# 1                                 79             No           High
# 2                                 88             No            Low
# 3                                113            Yes       Moderate
# 4                                 65             No           High
# 5                                 84             No            Low
#
#            Physical_Activity  Obesity_Index Diabetes_Status  \
# Patient_ID
# 1                  Sedentary           35.2              No
# 2                  Sedentary           21.3              No
# 3              Highly Active           32.0             Yes
# 4                  Sedentary           36.4              No
# 5                     Active           26.6              No
#
#            Family_History_Heart_Disease Diet_Quality Stress_Level  \
# Patient_ID
# 1                                    No         Good         High
# 2                                    No      Average       Medium
# 3                                    No         Good          Low
# 4                                   Yes      Average          Low
# 5                                    No         Good         High
#
#            Heart_Attack_History Medication_Usage  Triglycerides_Level  \
# Patient_ID
# 1                            No               No                  264
# 2                            No              Yes                  150
# 3                            No               No                  220
# 4                            No              Yes                  141
# 5                            No               No                  221
#
#             LDL_Level  HDL_Level  Heart_Attack_Outcome
# Patient_ID
# 1                 141         65                     0
# 2                  81         42                     0
# 3                 124         70                     1
# 4                  56         38                     1
# 5                 186         26                     0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 1 to 100000
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Age                           100000 non-null  int64
#  1   Gender                        100000 non-null  object
#  2   Cholesterol_Level             100000 non-null  int64
#  3   Blood_Pressure_Systolic       100000 non-null  int64
#  4   Blood_Pressure_Diastolic      100000 non-null  int64
#  5   Smoking_Status                100000 non-null  object
#  6   Alcohol_Intake                100000 non-null  object
#  7   Physical_Activity             100000 non-null  object
#  8   Obesity_Index                 100000 non-null  float64
#  9   Diabetes_Status               100000 non-null  object
#  10  Family_History_Heart_Disease  100000 non-null  object
#  11  Diet_Quality                  100000 non-null  object
#  12  Stress_Level                  100000 non-null  object
#  13  Heart_Attack_History          100000 non-null  object
#  14  Medication_Usage              100000 non-null  object
#  15  Triglycerides_Level           100000 non-null  int64
#  16  LDL_Level                     100000 non-null  int64
#  17  HDL_Level                     100000 non-null  int64
#  18  Heart_Attack_Outcome          100000 non-null  int64
# dtypes: float64(1), int64(8), object(10)
# memory usage: 15.3+ MB

# %%
sns.countplot(df, x = 'Gender', hue = 'Heart_Attack_Outcome')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.histplot(df, x = 'Cholesterol_Level', hue = 'Heart_Attack_Outcome')
# Out:
# <Axes: xlabel='Cholesterol_Level', ylabel='Count'>

# %%
sns.histplot(df, x = 'Blood_Pressure_Systolic', hue = 'Heart_Attack_Outcome')
# Out:
# <Axes: xlabel='Blood_Pressure_Systolic', ylabel='Count'>

# %%
sns.histplot(df, x = 'Blood_Pressure_Diastolic', hue = 'Heart_Attack_Outcome')
# Out:
# <Axes: xlabel='Blood_Pressure_Diastolic', ylabel='Count'>

# %%
df['Gender'] = df['Gender'].replace('Female', int(0))
df['Gender'] = df['Gender'].replace('Male', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\3425373255.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = df['Gender'].replace('Male', int(1))

# %%
df['Smoking_Status'].value_counts()
# Out:
# Smoking_Status
# No     69989
# Yes    30011
# Name: count, dtype: int64

# %%
df['Smoking_Status'] = df['Smoking_Status'].replace('No', int(0))
df['Smoking_Status'] = df['Smoking_Status'].replace('Yes', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\316772291.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Smoking_Status'] = df['Smoking_Status'].replace('Yes', int(1))

# %%
df['Alcohol_Intake'].value_counts()
# Out:
# Alcohol_Intake
# Moderate    40262
# Low         39772
# High        19966
# Name: count, dtype: int64

# %%
df['Alcohol_Intake'] = df['Alcohol_Intake'].replace('Low', int(0))
df['Alcohol_Intake'] = df['Alcohol_Intake'].replace('Moderate', int(1))
df['Alcohol_Intake'] = df['Alcohol_Intake'].replace('High', int(2))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\2519466088.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Alcohol_Intake'] = df['Alcohol_Intake'].replace('High', int(2))

# %%
df['Physical_Activity'].value_counts()
# Out:
# Physical_Activity
# Sedentary        50275
# Active           29810
# Highly Active    19915
# Name: count, dtype: int64

# %%
df['Physical_Activity'] = df['Physical_Activity'].replace('Sedentary', int(0))
df['Physical_Activity'] = df['Physical_Activity'].replace('Active', int(1))
df['Physical_Activity'] = df['Physical_Activity'].replace('Highly Active', int(2))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\3632774527.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Physical_Activity'] = df['Physical_Activity'].replace('Highly Active', int(2))

# %%
df['Diabetes_Status'].value_counts()
# Out:
# Diabetes_Status
# No     80155
# Yes    19845
# Name: count, dtype: int64

# %%
df['Diabetes_Status'] = df['Diabetes_Status'].replace('No', int(0))
df['Diabetes_Status'] = df['Diabetes_Status'].replace('Yes', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\214899147.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Diabetes_Status'] = df['Diabetes_Status'].replace('Yes', int(1))

# %%
df['Family_History_Heart_Disease'].value_counts()
# Out:
# Family_History_Heart_Disease
# No     74977
# Yes    25023
# Name: count, dtype: int64

# %%
df['Family_History_Heart_Disease'] = df['Family_History_Heart_Disease'].replace('No', int(0))
df['Family_History_Heart_Disease'] = df['Family_History_Heart_Disease'].replace('Yes', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\3629938683.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Family_History_Heart_Disease'] = df['Family_History_Heart_Disease'].replace('Yes', int(1))

# %%
df['Diet_Quality'].value_counts()
# Out:
# Diet_Quality
# Average    49818
# Poor       30088
# Good       20094
# Name: count, dtype: int64

# %%
df['Diet_Quality'] = df['Diet_Quality'].replace('Poor', int(0))
df['Diet_Quality'] = df['Diet_Quality'].replace('Average', int(1))
df['Diet_Quality'] = df['Diet_Quality'].replace('Good', int(2))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\2991120519.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Diet_Quality'] = df['Diet_Quality'].replace('Good', int(2))

# %%
df['Stress_Level'].value_counts()
# Out:
# Stress_Level
# Medium    50156
# Low       29983
# High      19861
# Name: count, dtype: int64

# %%
df['Stress_Level'] = df['Stress_Level'].replace('Low', int(0))
df['Stress_Level'] = df['Stress_Level'].replace('Medium', int(1))
df['Stress_Level'] = df['Stress_Level'].replace('High', int(2))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\1292254357.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Stress_Level'] = df['Stress_Level'].replace('High', int(2))

# %%
df['Heart_Attack_History'].value_counts()
# Out:
# Heart_Attack_History
# No     85023
# Yes    14977
# Name: count, dtype: int64

# %%
df['Heart_Attack_History'] = df['Heart_Attack_History'].replace('No', int(0))
df['Heart_Attack_History'] = df['Heart_Attack_History'].replace('Yes', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\2068073928.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Heart_Attack_History'] = df['Heart_Attack_History'].replace('Yes', int(1))

# %%
df['Medication_Usage'].value_counts()
# Out:
# Medication_Usage
# Yes    50079
# No     49921
# Name: count, dtype: int64

# %%
df['Medication_Usage'] = df['Medication_Usage'].replace('No', int(0))
df['Medication_Usage'] = df['Medication_Usage'].replace('Yes', int(1))
# Out:
# C:\Users\novit\AppData\Local\Temp\ipykernel_14980\1335365848.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Medication_Usage'] = df['Medication_Usage'].replace('Yes', int(1))

# %%
df.head()
# Out:
#             Age  Gender  Cholesterol_Level  Blood_Pressure_Systolic  \
# Patient_ID
# 1            76       0                156                       94
# 2            39       0                160                      185
# 3            85       1                254                      173
# 4            45       0                261                      187
# 5            48       1                206                      189
#
#             Blood_Pressure_Diastolic  Smoking_Status  Alcohol_Intake  \
# Patient_ID
# 1                                 79               0               2
# 2                                 88               0               0
# 3                                113               1               1
# 4                                 65               0               2
# 5                                 84               0               0
#
#             Physical_Activity  Obesity_Index  Diabetes_Status  \
# Patient_ID
# 1                           0           35.2                0
# 2                           0           21.3                0
# 3                           2           32.0                1
# 4                           0           36.4                0
# 5                           1           26.6                0
#
#             Family_History_Heart_Disease  Diet_Quality  Stress_Level  \
# Patient_ID
# 1                                      0             2             2
# 2                                      0             1             1
# 3                                      0             2             0
# 4                                      1             1             0
# 5                                      0             2             2
#
#             Heart_Attack_History  Medication_Usage  Triglycerides_Level  \
# Patient_ID
# 1                              0                 0                  264
# 2                              0                 1                  150
# 3                              0                 0                  220
# 4                              0                 1                  141
# 5                              0                 0                  221
#
#             LDL_Level  HDL_Level  Heart_Attack_Outcome
# Patient_ID
# 1                 141         65                     0
# 2                  81         42                     0
# 3                 124         70                     1
# 4                  56         38                     1
# 5                 186         26                     0

# %%
plt.figure(figsize = (12,8))
sns.heatmap(df.corr(numeric_only=True), annot= True, cmap = 'viridis')
# Out:
# <Axes: >

# %%
df.corr()['Heart_Attack_Outcome'].sort_values()
# Out:
# Diet_Quality                   -0.006526
# Triglycerides_Level            -0.003899
# HDL_Level                      -0.003492
# Physical_Activity              -0.002991
# Gender                         -0.001068
# Stress_Level                    0.000955
# Alcohol_Intake                  0.001807
# Heart_Attack_History            0.001919
# LDL_Level                       0.003568
# Medication_Usage                0.005468
# Blood_Pressure_Diastolic        0.140187
# Blood_Pressure_Systolic         0.148573
# Diabetes_Status                 0.250756
# Family_History_Heart_Disease    0.278858
# Cholesterol_Level               0.283860
# Obesity_Index                   0.296385
# Age                             0.298683
# Smoking_Status                  0.299025
# Heart_Attack_Outcome            1.000000
# Name: Heart_Attack_Outcome, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Heart_Attack_Outcome', axis= 1)
y = df['Heart_Attack_Outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\novit\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[ 8715  3784]
#  [ 2659 14842]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73     12499
#            1       0.80      0.85      0.82     17501
#
#     accuracy                           0.79     30000
#    macro avg       0.78      0.77      0.78     30000
# weighted avg       0.78      0.79      0.78     30000

# %%
X = df.drop('Heart_Attack_Outcome', axis= 1).values
y = df['Heart_Attack_Outcome'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.constraints import max_norm

# %%
model = Sequential()

model.add(Dense(18, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(9, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam' )

# %%
model.fit(x=X_train, y=y_train, epochs=25,batch_size= 256, validation_data=(X_test,y_test))
# Out:
# Epoch 1/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 0.6498 - val_loss: 0.4365
# Epoch 2/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4586 - val_loss: 0.3408
# Epoch 3/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3767 - val_loss: 0.3014
# Epoch 4/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3375 - val_loss: 0.2791
# Epoch 5/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3181 - val_loss: 0.2688
# Epoch 6/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3037 - val_loss: 0.2626
# Epoch 7/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2883 - val_loss: 0.2585
# Epoch 8/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2841 - val_loss: 0.2542
# Epoch 9/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2776 - val_loss: 0.2509
# Epoch 10/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2754 - val_loss: 0.2497
# Epoch 11/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2678 - val_loss: 0.2460
# Epoch 12/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.2645 - val_loss: 0.2433
# Epoch 13/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2611 - val_loss: 0.2410
# Epoch 14/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2576 - val_loss: 0.2361
# Epoch 15/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2551 - val_loss: 0.2321
# Epoch 16/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2511 - val_loss: 0.2291
# Epoch 17/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2468 - val_loss: 0.2277
# Epoch 18/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2437 - val_loss: 0.2229
# Epoch 19/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2449 - val_loss: 0.2212
# Epoch 20/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2412 - val_loss: 0.2205
# Epoch 21/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2432 - val_loss: 0.2211
# Epoch 22/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2391 - val_loss: 0.2202
# Epoch 23/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2376 - val_loss: 0.2197
# Epoch 24/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2353 - val_loss: 0.2185
# Epoch 25/25
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2378 - val_loss: 0.2179

# %%
from tensorflow.keras.models import load_model

# %%
model.save('heart_attack_log.keras')

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
predictions =  (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[10799  1700]
#  [ 1250 16251]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88     12499
#            1       0.91      0.93      0.92     17501
#
#     accuracy                           0.90     30000
#    macro avg       0.90      0.90      0.90     30000
# weighted avg       0.90      0.90      0.90     30000
